# %%
import pandas as pd
import matplotlib.pyplot as sns
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
appledf = pd.read_csv('apple_quality.csv')
appledf
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
col = ['Size','Sweetness','Crunchiness','Juiciness','Ripeness','Quality']
appledf = appledf[col]
appledf
# Out:
#           Size  Sweetness  Crunchiness  Juiciness  Ripeness Quality
# 0    -3.970049   5.346330    -1.012009   1.844900  0.329840    good
# 1    -1.195217   3.664059     1.588232   0.853286  0.867530    good
# 2    -0.292024  -1.738429    -0.342616   2.838636 -0.038033     bad
# 3    -0.657196   1.324874    -0.097875   3.637970 -3.413761    good
# 4     1.364217  -0.384658    -0.553006   3.030874 -1.303849    good
# ...        ...        ...          ...        ...       ...     ...
# 3996 -0.293118  -0.204020    -0.640196   0.024523 -1.087900    good
# 3997 -2.634515  -2.440461     0.657223   2.199709  4.763859     bad
# 3998 -4.008004   2.366397    -0.200329   2.161435  0.214488    good
# 3999  0.278540   0.121217    -1.154075   1.266677 -0.776571    good
# 4000       NaN        NaN          NaN        NaN       NaN     NaN
#
# [4001 rows x 6 columns]

# %%
appledf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         4000 non-null   float64
#  1   Sweetness    4000 non-null   float64
#  2   Crunchiness  4000 non-null   float64
#  3   Juiciness    4000 non-null   float64
#  4   Ripeness     4000 non-null   float64
#  5   Quality      4000 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 187.7+ KB

# %%
appledf.dropna(inplace=True)
# Out:
# C:\Users\Clarina Jones\AppData\Local\Temp\ipykernel_15588\3496322991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   appledf.dropna(inplace=True)

# %%
appledf.isna().sum()
# Out:
# Size           0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Quality        0
# dtype: int64

# %%
appledf['Quality'] = appledf['Quality'].replace({'good': 1, 'bad': 0})
# Out:
# C:\Users\Clarina Jones\AppData\Local\Temp\ipykernel_15588\2516320153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   appledf['Quality'] = appledf['Quality'].replace({'good': 1, 'bad': 0})

# %%
X = appledf.drop(columns=['Quality'])
Y = appledf['Quality']

# %%
X
# Out:
#           Size  Sweetness  Crunchiness  Juiciness  Ripeness
# 0    -3.970049   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...        ...          ...        ...       ...
# 3995  0.059386  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540   0.121217    -1.154075   1.266677 -0.776571
#
# [4000 rows x 5 columns]

# %%
Y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 3995    0
# 3996    1
# 3997    0
# 3998    1
# 3999    1
# Name: Quality, Length: 4000, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,Y_train)
# Out:
# 0.24988470908410854

# %%
Linear_accuracy = model.score(X_test,Y_test)
print(Linear_accuracy)
# Out:
# 0.23609986960474605

# %%
model_las = Lasso(alpha = 0.1,max_iter = 1,tol = 0.001)
model_las.fit(X_train,Y_train)
# Out:
# C:\Users\Clarina Jones\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.557e+01, tolerance: 8.000e-01
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1, max_iter=1, tol=0.001)

# %%
model_las.score(X_train,Y_train)
# Out:
# 0.1993579036482963

# %%
Lasso_accuracy = model_las.score(X_test,Y_test)
print(Lasso_accuracy)
# Out:
# 0.1889723251105132

# %%
model_rid = Ridge(alpha = 0.1,max_iter = 1,tol = 0.001)
model_rid.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.1, max_iter=1, tol=0.001)

# %%
model_rid.score(X_train,Y_train)
# Out:
# 0.2498847090599744

# %%
Ridge_accuracy = model_rid.score(X_test,Y_test)
print(Ridge_accuracy)
# Out:
# 0.23609983732381512
